# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.8/871.8 kB 11.3 MB/s eta 0:00:00
# ...

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 103MB/s]
# Ultralytics YOLOv8.2.91 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 134k/134k [00:00<00:00, 7.01MB/s]
# image 1/1 /content/drive/MyDrive/yolo_data/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.4ms
# Speed: 11.5ms preprocess, 40.4ms inference, 812.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.91 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.9/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/yolo_data
# Out:
# /content/drive/MyDrive/yolo_data

# %%
# !ls
# Out:
# bus.jpg  data.yaml  runs  test	train  val  Videos  yolov8n.pt

# %%
# Training using pretrained YOLO model

# %%
# %cd /content/drive/MyDrive/yolo_data

# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=150 imgsz=256 plots=True project=/content/drive/MyDrive/yolo_data/pt_training augment=True batch=32 lr0=0.01 optimizer="auto" patience = 100  lrf=0.01
# Out:
# /content/drive/MyDrive/yolo_data
# ...
# 100% 21.5M/21.5M [00:00<00:00, 174MB/s]
# Ultralytics YOLOv8.2.91 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#Testing using pre-trained

# %%
# %cd /content/drive/MyDrive/yolo_data
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolo_data/pt_training/train/weights/best.pt conf=0.7 source=/content/drive/MyDrive/yolo_data/test/images
# Out:
# /content/drive/MyDrive/yolo_data
# Ultralytics YOLOv8.2.91 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/136 /content/drive/MyDrive/yolo_data/test/images/0d6e6efd-41ee-4add-894c-5354b40f3712_frame_1365.jpg: 256x160 1 Makeup-Product, 54.6ms
# image 2/136 /content/drive/MyDrive/yolo_data/test/images/0d6e6efd-41ee-4add-894c-5354b40f3712_frame_227.jpg: 256x160 1 Makeup-Product, 14.5ms
# image 3/136 /content/drive/MyDrive/yolo_data/test/images/0d6e6efd-41ee-4add-894c-5354b40f3712_frame_579.jpg: 256x160 1 Makeup-Product, 14.1ms
# image 4/136 /content/drive/MyDrive/yolo_data/test/images/1b437b4a-3f37-49fb-99d5-ce42c80ef7e8_frame_1607.jpg: 256x160 1 Makeup-Product, 11.4ms
# image 5/136 /content/drive/MyDrive/yolo_data/test/images/1b437b4a-3f37-49fb-99d5-ce42c80ef7e8_frame_82.jpg: 256x160 1 Makeup-Product, 13.0ms
# ...

# %%
# Testing on Videos

# %%
# %cd /content/drive/MyDrive/yolo_data
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolo_data/pt_training/train/weights/best.pt  conf=0.7 source=/content/drive/MyDrive/yolo_data/Videos
# Out:
# /content/drive/MyDrive/yolo_data
# Ultralytics YOLOv8.2.91 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/2 (frame 1/828) /content/drive/MyDrive/yolo_data/Videos/6938905013653605637.mp4: 256x160 1 Makeup-Product, 76.4ms
# video 1/2 (frame 2/828) /content/drive/MyDrive/yolo_data/Videos/6938905013653605637.mp4: 256x160 1 Makeup-Product, 10.0ms
# video 1/2 (frame 3/828) /content/drive/MyDrive/yolo_data/Videos/6938905013653605637.mp4: 256x160 1 Makeup-Product, 11.4ms
# video 1/2 (frame 4/828) /content/drive/MyDrive/yolo_data/Videos/6938905013653605637.mp4: 256x160 1 Makeup-Product, 9.8ms
# video 1/2 (frame 5/828) /content/drive/MyDrive/yolo_data/Videos/6938905013653605637.mp4: 256x160 1 Makeup-Product, 9.9ms
# video 1/2 (frame 6/828) /content/drive/MyDrive/yolo_data/Videos/6938905013653605637.mp4: 256x160 1 Makeup-Product, 13.3ms
# ...

# %%
# Untrained YOLO Model

# %%
# %cd /content/drive/MyDrive/yolo_data

# !yolo task=detect mode=train model=yolov8s data= data.yaml epochs=150 imgsz=256 plots=True project=/content/drive/MyDrive/yolo_data/un_training augment=True batch=32 lr0=0.01
# Out:
# /content/drive/MyDrive/yolo_data
# Ultralytics YOLOv8.2.87 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#Testing using untrained Yolo

# %%
# %cd /content/drive/MyDrive/yolo_data
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolo_data/un_training/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/yolo_data/test/images
# Out:
# /content/drive/MyDrive/yolo_data
# Ultralytics YOLOv8.2.87 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/136 /content/drive/MyDrive/yolo_data/test/images/0d6e6efd-41ee-4add-894c-5354b40f3712_frame_1365.jpg: 256x160 1 Makeup-Product, 42.6ms
# image 2/136 /content/drive/MyDrive/yolo_data/test/images/0d6e6efd-41ee-4add-894c-5354b40f3712_frame_227.jpg: 256x160 1 Makeup-Product, 15.4ms
# image 3/136 /content/drive/MyDrive/yolo_data/test/images/0d6e6efd-41ee-4add-894c-5354b40f3712_frame_579.jpg: 256x160 1 Makeup-Product, 7.8ms
# image 4/136 /content/drive/MyDrive/yolo_data/test/images/1b437b4a-3f37-49fb-99d5-ce42c80ef7e8_frame_1607.jpg: 256x160 1 Makeup-Product, 7.3ms
# image 5/136 /content/drive/MyDrive/yolo_data/test/images/1b437b4a-3f37-49fb-99d5-ce42c80ef7e8_frame_82.jpg: 256x160 1 Makeup-Product, 7.4ms
# ...

# %%
# %cd /content/drive/MyDrive/yolo_data
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolo_data/un_training/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/yolo_data/Videos
# Out:
# /content/drive/MyDrive/yolo_data
# Ultralytics YOLOv8.2.87 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/2 (frame 1/3568) /content/drive/MyDrive/yolo_data/Videos/7103939217427926278.mp4: 256x160 (no detections), 41.1ms
# video 1/2 (frame 2/3568) /content/drive/MyDrive/yolo_data/Videos/7103939217427926278.mp4: 256x160 (no detections), 8.9ms
# video 1/2 (frame 3/3568) /content/drive/MyDrive/yolo_data/Videos/7103939217427926278.mp4: 256x160 1 Makeup-Product, 8.9ms
# video 1/2 (frame 4/3568) /content/drive/MyDrive/yolo_data/Videos/7103939217427926278.mp4: 256x160 1 Makeup-Product, 9.4ms
# video 1/2 (frame 5/3568) /content/drive/MyDrive/yolo_data/Videos/7103939217427926278.mp4: 256x160 (no detections), 8.5ms
# video 1/2 (frame 6/3568) /content/drive/MyDrive/yolo_data/Videos/7103939217427926278.mp4: 256x160 (no detections), 9.6ms
# ...
